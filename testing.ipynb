# %%
from utils import *
from gtmatrix import *
from spectrum import *
from dem import *
from config import *

from astropy import units as u
# Out:
#  ChiantiPy version 0.15.1
#  using cli
#  using CLI for selections
# Traceback (most recent call last):
#   File "/Users/bella/anaconda3/envs/lasp_ENV/lib/python3.12/site-packages/ChiantiPy/tools/data.py", line 45, in <module>
#     Xuvtop = os.environ['XUVTOP']
#              ~~~~~~~~~~^^^^^^^^^^
#   File "<frozen os>", line 714, in __getitem__
# KeyError: 'XUVTOP'
# /Users/bella/anaconda3/envs/lasp_ENV/lib/python3.12/site-packages/ChiantiPy/tools/data.py:78: UserWarning: XUVTOP environment variable not set. You will not be able to access any data from the CHIANTI database.
#   warnings.warn(

# %% [markdown]
# #### Initialize basic enviroment and directories

# %%
check_environment(PATH_CONFIG) # add directions on how to download chianti database !
create_directories(PATH_CONFIG)
# Out:
# Warning: XUVTOP environment variable not set.
# EXUVTOP environment set to /Users/bella/Desktop/LASP/Stars/CHIANTI_10.1_database

# %% [markdown]
# #### Create GTMatrix

# %%
gtmatrix = GTMatrix(STAR_CONFIG, GTMAT_CONFIG, PATH_CONFIG)

# Create GTMatrix 
gtmatrix.initialize()

gtmatrix.load_line_data()

gtmatrix.generate_all_matrices()

gtmatrix.generate_heatmap()
# Out:
# Initialized GTMatrix with 200 temperature points and 149901 wavelength points
# Loaded emission line data: 15 unique ions
# Loaded existing matrix: gtmat_EX_w1_w1500_t4_t8_r100_p17_sol0.npy
# Heatmap saved to plots/EX_gtmat_heatmap
